# %%
import pandas as pd

# Read first 5 lines of the dataset to check the dataset
df_sample = pd.read_csv('/content/fraud_detection_dataset/financial_fraud_detection_dataset.csv', nrows=5)
print(df_sample.columns.tolist())
print(df_sample.dtypes)
# Out:
# ['transaction_id', 'timestamp', 'sender_account', 'receiver_account', 'amount', 'transaction_type', 'merchant_category', 'location', 'device_used', 'is_fraud', 'fraud_type', 'time_since_last_transaction', 'spending_deviation_score', 'velocity_score', 'geo_anomaly_score', 'payment_channel', 'ip_address', 'device_hash']
# transaction_id                  object
# timestamp                       object
# sender_account                  object
# receiver_account                object
# amount                         float64
# transaction_type                object
# merchant_category               object
# location                        object
# device_used                     object
# is_fraud                          bool
# fraud_type                     float64
# time_since_last_transaction    float64
# spending_deviation_score       float64
# velocity_score                   int64
# geo_anomaly_score              float64
# payment_channel                 object
# ...
